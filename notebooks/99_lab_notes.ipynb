# %% [markdown]
# # 📓 Notebook 99: Lab Notes — Learning Journal
#
# **Purpose:** Document your learning journey, experiments, and insights throughout this project.
#
# **What to capture:** What clicked, what confused you, experiments you tried, and ideas for improvement.

# %% [markdown]
# ## 📅 Journal Entry Template
#
# Use this template for each session or experiment:
#
# ---
#
# ### Date: [YYYY-MM-DD]
#
# **Session Goal:**
# - What did I aim to accomplish today?
#
# **What Clicked 💡:**
# - Concepts that finally made sense
# - Aha moments
#
# **What Confused Me 😕:**
# - Concepts still unclear
# - Errors encountered
#
# **Experiments Tried 🧪:**
# - Parameter changes (learning rate, batch size, epochs, etc.)
# - Architecture modifications
# - Results observed
#
# **Key Takeaways 🎯:**
# - Main lessons learned
# - Skills practiced
#
# **Next Steps ⏭️:**
# - What to try next session
# - Questions to investigate
#
# ---

# %% [markdown]
# ## 📊 Experiment Log
#
# Track hyperparameter experiments here:
#
# | Date | Experiment | Params Changed | Train Loss | Val Loss | Test F1 | Notes |
# |------|------------|----------------|------------|----------|---------|-------|
# | 2024-XX-XX | Baseline | lr=5e-4, batch=8, epochs=5 | ? | ? | ? | First run |
# | | | | | | | |
# | | | | | | | |
#
# ### Ideas to Try:
# - [ ] Increase epochs to 10 or 20
# - [ ] Try learning rates: 1e-4, 1e-3
# - [ ] Experiment with batch sizes: 16, 32
# - [ ] Add dropout layers (e.g., 0.5 after FC1)
# - [ ] Try BCEWithLogitsLoss instead of BCELoss
# - [ ] Implement learning rate scheduling
# - [ ] Add more conv layers (deeper network)
# - [ ] Try transfer learning with pretrained ResNet18

# %% [markdown]
# ## 💡 Insights & Reflections
#
# ### On Data Augmentation
# **Initial thoughts:**
#
# **After implementation:**
#
# **Key insight:**
#
# ---
#
# ### On CNN Architecture
# **Initial thoughts:**
#
# **After implementation:**
#
# **Key insight:**
#
# ---
#
# ### On Training Dynamics
# **Initial thoughts:**
#
# **After implementation:**
#
# **Key insight:**
#
# ---
#
# ### On Evaluation Metrics
# **Initial thoughts:**
#
# **After implementation:**
#
# **Key insight:**
#
# ---

# %% [markdown]
# ## 🧠 Skills Practiced
#
# Check off skills as you practice them:
#
# ### Data Handling
# - [ ] Loading images with PIL
# - [ ] Building custom Dataset classes
# - [ ] Using DataLoader with batching and shuffling
# - [ ] Applying transforms and augmentations
#
# ### PyTorch Fundamentals
# - [ ] Building nn.Module classes
# - [ ] Defining layers in __init__
# - [ ] Implementing forward passes
# - [ ] Moving models and data to GPU
# - [ ] Understanding tensor shapes at each layer
#
# ### Training
# - [ ] Implementing training loops
# - [ ] Zero gradients, forward, backward, step
# - [ ] Tracking losses over epochs
# - [ ] Implementing validation loops
# - [ ] Using model.train() and model.eval() modes
#
# ### Evaluation
# - [ ] Running inference with no_grad
# - [ ] Converting probabilities to class labels
# - [ ] Generating classification reports
# - [ ] Interpreting precision, recall, F1
# - [ ] Understanding clinical implications of errors
#
# ### Medical AI Considerations
# - [ ] Understanding ethical implications
# - [ ] Recognizing limitations of educational models
# - [ ] Considering false negative vs false positive trade-offs
# - [ ] Thinking about threshold tuning for clinical use

# %% [markdown]
# ## 🚀 Future Improvements
#
# ### Short-term (Next Sessions)
# 1.
# 2.
# 3.
#
# ### Medium-term (This Month)
# 1.
# 2.
# 3.
#
# ### Long-term (Learning Goals)
# 1.
# 2.
# 3.
#
# ---
#
# ## 📚 Resources & References
#
# **Papers:**
# - [Link to PCam dataset paper or relevant research]
#
# **Tutorials:**
# - [PyTorch official tutorials]
# - [Medical imaging AI resources]
#
# **Tools:**
# - [Useful libraries or frameworks discovered]
#
# ---
#
# **Remember:** This is a learning project. Every mistake is a lesson. Keep documenting, keep experimenting, keep learning! 🎓✨
